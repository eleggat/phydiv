# %% [markdown]
# # Tree construction

# %% [markdown]
# Documentation for `toytree` is found at https://eaton-lab.org/toytree/

# %%
#imports
import numpy as np
import toytree

# %%
# Generate a random bifurcating tree with 30 tips
n_tips = 30
tree = toytree.rtree.rtree(ntips=10, seed = 123)

# Display the tree
tree.draw(ts='p');
# Out:
# <div class="toyplot" id="t0141a692eba1449493f772cf6c4cd27a" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="300.0px" height="300.0px" viewBox="0 0 300.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tbc7270e6e85543429b19baf7a206513e"><g class="toyplot-coordinates-Cartesian" id="te83ffeb0eff845c28ceae9a4a61f3a88"><clipPath id="teee42d7a63c7478bb2d815724fff84bd"><rect x="35.0" y="35.0" width="230.0" height="230.0"></rect></clipPath><g clip-path="url(#teee42d7a63c7478bb2d815724fff84bd)"><g class="toytree-mark-Toytree" id="t09baa43c501c418cbda25e45e879fe9a"><g class="toytree-Edges" style="stroke:r
# ...

# %%
# an example tree
tree = toytree.rtree.rtree(ntips=15, seed=123)# returns the three drawing objects
tree.style
# Out:
# {
# tree_style: None,
# height: None,
# width: None,
# layout: 'r',
# edge_type: 'p',
# edge_colors: None,
# edge_widths: None,
# node_mask: None,
# node_colors: None,
# node_sizes: 0.0,
# node_markers: 'o',
# node_hover: None,
# node_labels: False,
# node_as_edge_data: False,
# tip_labels: True,
# tip_labels_colors: None,
# tip_labels_angles: None,
# tip_labels_align: None,
# edge_style: {
#     stroke: (0.145, 0.145, 0.145, 1.0),
#     stroke_width: 2.0,
#     stroke_opacity: None,
#     stroke_linecap: 'round',
#     stroke_dasharray: None,
# },
# node_style: {
#     fill: (0.4, 0.7607843137254902, 0.6470588235294118, 1.0),
#     fill_opacity: None,
#     stroke: '#262626',
#     stroke_width: 1.5,
#     stroke_opacity: None,
# },
# node_labels_style: {
#     fill: (0.145, 0.145, 0.145, 1.0),
#     fill_opacity: 1.0,
#     font_size: 9,
#     font_weight: 300,
#     font_family: 'Helvetica',
#     anchor_shift: 0,
#     baseline_shift: 0,
#     text_anchor: 'middle',
# },
# ...

# %%
unit_tree = toytree.rtree.baltree(20, random_names=True)
unit_tree.draw(scale_bar=True, ts='s', node_hover=True);
# Out:
# <div class="toyplot" id="t97c645d7aac54099a26f80aa8034f14e" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="300.0px" height="np.float64(537.0)px" viewBox="0 0 300.0 np.float64(537.0)" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tca16988652fa4d4b8c17fb666890ced1"><g class="toyplot-coordinates-Cartesian" id="t796d05d81a384f0592f378bb1215ef3e"><clipPath id="tadfe204ade194022b31ecbf8f2a380a4"><rect x="35.0" y="35.0" width="230.0" height="np.float64(467.0)"></rect></clipPath><g clip-path="url(#tadfe204ade194022b31ecbf8f2a380a4)"><g class="toytree-mark-Toytree" id="t0b515b715c1a4744a985d104c51569c9"><g c
# ...

# %% [markdown]
# Trees with more than 10 nodes aren't visualizing. Not sure why. Try with ASCII drawing instead

# %%
sp_tree = toytree.rtree.baltree(100, random_names=False)
#sp_tree.treenode.draw_ascii()
sp_tree.get_tip_labels()
# Out:
# ['r0',
#  'r1',
#  'r2',
#  'r3',
#  'r4',
#  'r5',
#  'r6',
#  'r7',
#  'r8',
#  'r9',
#  'r10',
#  'r11',
#  'r12',
#  'r13',
#  'r14',
#  'r15',
#  'r16',
#  'r17',
#  'r18',
#  'r19',
#  'r20',
#  'r21',
#  'r22',
#  'r23',
#  'r24',
#  'r25',
#  'r26',
#  'r27',
#  'r28',
#  'r29',
#  'r30',
#  'r31',
#  'r32',
#  'r33',
#  'r34',
#  'r35',
#  'r36',
#  'r37',
#  'r38',
#  'r39',
#  'r40',
#  'r41',
#  'r42',
#  'r43',
#  'r44',
#  'r45',
#  'r46',
#  'r47',
#  'r48',
#  'r49',
#  'r50',
#  'r51',
#  'r52',
#  'r53',
#  'r54',
#  'r55',
#  'r56',
#  'r57',
#  'r58',
#  'r59',
#  'r60',
#  'r61',
#  'r62',
#  'r63',
#  'r64',
#  'r65',
#  'r66',
#  'r67',
#  'r68',
#  'r69',
#  'r70',
#  'r71',
#  'r72',
#  'r73',
#  'r74',
#  'r75',
#  'r76',
#  'r77',
#  'r78',
#  'r79',
#  'r80',
#  'r81',
#  'r82',
#  'r83',
#  'r84',
#  'r85',
#  'r86',
#  'r87',
#  'r88',
#  'r89',
#  'r90',
#  'r91',
#  'r92',
#  'r93',
#  'r94',
#  'r95',
#  'r96',
#  'r97',
#  'r98',
#  'r99']

# %% [markdown]
# Need to put tip names in a list, and make a distance matrix of all tips

# %%
sp_tree.distance.get_tip_distance_matrix(df=True)
# Out:
#            r0        r1        r2        r3        r4        r5        r6  \
# r0   0.000000  0.571429  0.571429  0.857143  0.857143  0.857143  1.142857
# r1   0.571429  0.000000  0.285714  0.857143  0.857143  0.857143  1.142857
# r2   0.571429  0.285714  0.000000  0.857143  0.857143  0.857143  1.142857
# r3   0.857143  0.857143  0.857143  0.000000  0.571429  0.571429  1.142857
# r4   0.857143  0.857143  0.857143  0.571429  0.000000  0.285714  1.142857
# ..        ...       ...       ...       ...       ...       ...       ...
# r95  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
# r96  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
# r97  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
# r98  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
# r99  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
#
#            r7        r8        r9  ...       r90       r91       r92  \
# ...
